# %% [markdown]
# # HTML

# %% [markdown]
# ## 1. Listes numérotées et puces

# %% [markdown]
# <body>
#     <h3>Liste numérotée : </h3>
#     <ol>
#         <li>python</li>
#         <li>linux</li>
#         <li>pycharm</li>
#     </ol>
#     <h3>Puces classiques : </h3>
#     <ul>
#         <li>python</li>
#         <li>linux</li>
#     </ul>
#     <a href="www.google.com"> Google</a>
# </body>

# %% [markdown]
# ## 2. Images et liens

# %% [markdown]
# <body>
#     <img src="assets/logo.jpeg" width="150" alt="Python Logo">
#     <br>
#     <br> <a href="01_next_page.html"> Page suivante</a>
#     <br> <a href="./02_table.html"> Page table</a>
#     <br> <a href="./03_input.html"> Page formulaire</a>
#     <br> <a href="./04_style.html"> Page style CC5</a>
#     <br> <a href="http://www.google.com"> Google.com</a>
# </body>

# %% [markdown]
# ## 3. Tableau

# %% [markdown]
# <body>
#     <table border="1">
#         <thead>
#             <th>UserID</th>
#             <th>Rating</th>
#             <th>Age</th>
#         </thead>
#         <tr>
#             <td>001</td>
#             <td>4.5</td>
#             <td>25</td>
#         </tr>
#         <tr>
#             <td>002</td>
#             <td>4</td>
#             <td>23</td>
#         </tr>
#         <tr>
#             <td>003</td>
#             <td>5</td>
#             <td>21</td>
#         </tr>
#     </table>
# </body>

# %% [markdown]
# ## 4. Formulaire

# %% [markdown]
# <body>
#     <form>
#         <h3>Exemple de formulaire : </h3>
#         <input id="name" type="text" placeholder="Nom et prénom"> Nom et prénom <br> <br>
#         <input type="email" value="mail@exemple.com"> Email <br> <br>
#         <input type="date"> Date de souscription <br> <br>
#         <input type="checkbox" pname="Permis"> Avez-vous le permis de conduire ?<br> <br>
#         <input type="number"> Nombre de vélos <br> <br>
#         <input type="password" > Mots de passe <br> <br>
#     </form>
# </body>

# %% [markdown]
# ## 5. Mise en page

# %% [markdown]
# <hrml>
#     <head>
#         <style>
#             .style-1{
#                 font-family: Arial;
#                 font-size: 20px;
#                 background: #1EAEDB;
#                 width: 100px
#             }
#             .test {
#                 color: red;
#                 font-size: 40px
#             }
#         </style>
#         <link rel="stylesheet" href="assets/styles.css">
#         <title>Titre onglet</title>
#     </head>
#     <body>
#         <h1 style="color: red; font-size: 40px">Page avec plus de style</h1>
#         <ol>
#             <li style="font-family: Arial; font-weight: bold">python</li>
#             <li class="style-1">linux</li>
#             <li class="test">psycharm</li>
#         </ol>
#     </body>
# </hrml>

# %% [markdown]
# ## 6. Exercice

# %% [markdown]
# #### 1. Créer une cellule **markdown**
# #### 2. Formulaire avec nom, prénom, adresse-mail et âge
#
# <body>
#     <form>
#         <h3>Exemple de formulaire : </h3>
#         <input id="name" type="text" placeholder="Nom et prénom"> Nom et prénom <br> <br>
#         <input type="email" value="mail@exemple.com"> Email <br> <br>
#         <input type="number"> Quel est votre âge ? <br> <br>
#     </form>
# </body>
#
# #### 3. Liste à puces dans laquelle on peut énumérer 3 passes-temps préférés
#
# <body>
#     <h3>Mes 3 passe-temps préférés: </h3>
#     <ul>
#         <li>Lire</li>
#         <li>Regarder des séries/films</li>
#         <li>Jouer à des jeux de sociétés</li>
#     </ul>
# </body>
#
# #### 4. Tableau de produits avec les colonnes : Nom du produit, Prix, Quantité
#
# <body>
#     <table border="1">
#         <thead>
#             <th>Nom du produit</th>
#             <th>Prix</th>
#             <th>Quantité</th>
#         </thead>
#         <tr>
#             <td>Tablette</td>
#             <td>350€</td>
#             <td>10</td>
#         </tr>
#         <tr>
#             <td>Piano</td>
#             <td>1000€</td>
#             <td>6</td>
#         </tr>
#         <tr>
#             <td>Livre</td>
#             <td>7.5€</td>
#             <td>35</td>
#         </tr>
#     </table>
# </body>
